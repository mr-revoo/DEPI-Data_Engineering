# %%
import pandas as pd

# %%
fl = pd.read_csv('tested.csv')

fl
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
fz = fl[fl['Ticket'] > '5000']
fz
# Out:
#      PassengerId  Survived  Pclass  \
# 5            897         0       3
# 9            901         0       3
# 11           903         0       1
# 14           906         1       1
# 15           907         1       2
# ..           ...       ...     ...
# 405         1297         0       2
# 409         1301         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 5                           Svensson, Mr. Johan Cervin    male  14.0      0
# 9                              Davies, Mr. John Samuel    male  21.0      2
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 15       del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
fl.rename(columns={"Sibsp": "Nigga"},inplace=True)
fl
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
